# %%
import sys 
import os
from os import rename, listdir 
import pandas as pd

# %%
root = '/mnt/disk2/data/private_data/SMhospital/capsule/1 preprocessed'

label = pd.read_csv(root + '/label.csv', index_col = 0)
label
# Out:
#                                                     negative  positive  \
# BK___02-02-14___1014671.jpg                                0         1
# BS___00-42-54___1005149.jpg                                0         1
# BS___00-42-54___1005150.jpg                                0         1
# BS___00-48-17___1005795.jpg                                0         1
# BS___01-01-12___1007346.jpg                                0         1
# BS___01-01-13___1007348.jpg                                0         1
# BS___01-01-56___1007433.jpg                                0         1
# BS___01-02-46___1007534.jpg                                0         1
# BS___01-31-27___1010976.jpg                                0         1
# BS___01-36-40___1011602.jpg                                0         1
# CGB___01-17-03___1009248.jpg                               0         1
# CGB___01-18-12___1009386.jpg                               0         1
# ...

# %%
files = listdir(root + '/database')
files
# Out:
# ['김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_f_-_-.jpg',
# ...

# %%
os.chdir(root + '/database')

# %%
listdir()
# Out:
# ['김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_-_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r1_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r2_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_-.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_ab.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_mb.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_-_r3_eh.jpg',
#  '김 민경 (19998616) 31 Aug 18_1_frame_04366__c_f_-_-.jpg',
# ...

# %%
[i for i in label.index if 'annotation' in i]
# Out:
# ['박 명자 (28372171) 10 Dec 18_1_frame_14393_annotation.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_12059_annotation.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_10540_annotation.jpg',
#  '오 종임 (23245336) 27 Aug 18_1_frame_03422_annotation.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_13777_annotation.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_10562_annotation.jpg',
#  '오 종임 (23245336) 27 Aug 18_1_frame_03955_annotation.jpg',
#  '이 수한 (27780793) 19 Nov 18_1_frame_10232_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_18534_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_18536_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_18537_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_18538_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_18539_annotation.jpg',
#  'Gang dae gue (30423812) 28 Oct 16_1_frame_19214_annotation.jpg',
# ...

# %%
anno_files = [''.join(i.split('_annotation')) for i in label.index if 'annotation' in i]

# %%
[i for i in files if '박 명자 (28372171) 10 Dec 18_1_frame_14393' in i]
# Out:
# ['박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_-_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_-_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_-_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_-_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r1_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r1_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r1_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r1_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r2_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r2_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r2_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r2_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r3_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r3_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r3_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_r3_eh.jpg',
# ...

# %%
sample = '박 명자 (28372171) 10 Dec 18_1_frame_14393__c_-_-_-.jpg'

# %%
sample.split('__c')[0] + '_annotation__c' + sample.split('__c')[1]
# Out:
# '박 명자 (28372171) 10 Dec 18_1_frame_14393_annotation__c_-_-_-.jpg'

# %%
for filename in files:  
    raw = filename.split('__c')[0] + '.jpg'
    if raw in anno_files:
#         new_filename = filename.replace(, 'ENTIRE_rgb_' + model)
        new_filename = filename.split('__c')[0] + '_annotation__c' + filename.split('__c')[1]
        print(filename, '\n', '-->', new_filename + '\n')
        os.rename(filename, new_filename)
# Out:
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_-_-.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_-_-.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_-_ab.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_-_ab.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_-_mb.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_-_mb.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_-_eh.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_-_eh.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_r1_-.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_-.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_r1_ab.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_ab.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_r1_mb.jpg
#  --> 박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_mb.jpg
#
# 박 명자 (28372171) 10 Dec 18_1_frame_08634__c_-_r1_eh.jpg
# ...

# %%
[i for i in listdir() if 'annotation'in i]
# Out:
# ['박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r1_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r2_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r2_mb.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r2_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r3_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r3_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_-_r3_eh.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_f_-_-.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_f_-_ab.jpg',
#  '박 명자 (28372171) 10 Dec 18_1_frame_08634_annotation__c_f_-_mb.jpg',
# ...
